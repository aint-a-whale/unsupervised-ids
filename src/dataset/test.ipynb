# %%
import json

# %%
with open('dataset/features/mapping/boolean.json') as file:
    f = json.load(file)

# %%
print(*list(f.values()), sep='\n')
# Out:
# fwd_psh_flags
# fwd_urg_flags
# fin_flag_cnt
# syn_flag_cnt
# rst_flag_cnt
# psh_flag_cnt
# ack_flag_cnt
# urg_flag_cnt
# cwe_flag_count
# ece_flag_cnt
# dst_port
# timestamp
# bwd_psh_flags
# bwd_urg_flags
# fwd_byts_per_b_avg
# fwd_pkts_per_b_avg
# fwd_blk_rate_avg
# bwd_byts_per_b_avg
# bwd_pkts_per_b_avg
# bwd_blk_rate_avg
